# %% [markdown]
# # Cement Manufacturing Dataset
# ## by HAMZAT ABDULRAHMAN

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# #### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from matplotlib import rcParams

# %matplotlib inline

# %% [markdown]
# ### Data Gathering

# %%
concrete = pd.read_csv("concrete.csv")
concrete.head(5)
# Out:
#    cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0   141.3  212.0    0.0  203.5           0.0      971.8    748.5   28
# 1   168.9   42.2  124.3  158.3          10.8     1080.8    796.2   14
# 2   250.0    0.0   95.7  187.4           5.5      956.9    861.2   28
# 3   266.0  114.0    0.0  228.0           0.0      932.0    670.0   28
# 4   154.8  183.4    0.0  193.3           9.1     1047.4    696.7   28
#
#    strength
# 0     29.89
# 1     23.51
# 2     29.22
# 3     45.85
# 4     18.29

# %% [markdown]
# ### Assessing

# %%
concrete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cement        1030 non-null   float64
#  1   slag          1030 non-null   float64
#  2   ash           1030 non-null   float64
#  3   water         1030 non-null   float64
#  4   superplastic  1030 non-null   float64
#  5   coarseagg     1030 non-null   float64
#  6   fineagg       1030 non-null   float64
#  7   age           1030 non-null   int64
#  8   strength      1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
concrete.duplicated().sum()
# Out:
# 25

# %%
concrete.describe()
# Out:
#             cement         slag          ash        water  superplastic  \
# count  1030.000000  1030.000000  1030.000000  1030.000000   1030.000000
# mean    281.167864    73.895825    54.188350   181.567282      6.204660
# std     104.506364    86.279342    63.997004    21.354219      5.973841
# min     102.000000     0.000000     0.000000   121.800000      0.000000
# 25%     192.375000     0.000000     0.000000   164.900000      0.000000
# 50%     272.900000    22.000000     0.000000   185.000000      6.400000
# 75%     350.000000   142.950000   118.300000   192.000000     10.200000
# max     540.000000   359.400000   200.100000   247.000000     32.200000
#
#          coarseagg      fineagg          age     strength
# count  1030.000000  1030.000000  1030.000000  1030.000000
# mean    972.918932   773.580485    45.662136    35.817961
# std      77.753954    80.175980    63.169912    16.705742
# min     801.000000   594.000000     1.000000     2.330000
# 25%     932.000000   730.950000     7.000000    23.710000
# 50%     968.000000   779.500000    28.000000    34.445000
# 75%    1029.400000   824.000000    56.000000    46.135000
# max    1145.000000   992.600000   365.000000    82.600000

# %%
concrete.isna().sum()
# Out:
# cement          0
# slag            0
# ash             0
# water           0
# superplastic    0
# coarseagg       0
# fineagg         0
# age             0
# strength        0
# dtype: int64

# %%
concrete.sample(5)
# Out:
#      cement  slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 18    190.7   0.0  125.4  162.1           7.8     1090.0    804.0    3
# 526   500.0   0.0    0.0  200.0           0.0     1125.0    613.0    3
# 787   307.0   0.0    0.0  193.0           0.0      968.0    812.0   90
# 988   238.0   0.0    0.0  185.0           0.0     1118.0    789.0   28
# 623   380.0   0.0    0.0  228.0           0.0      932.0    670.0  270
#
#      strength
# 18      15.04
# 526     26.06
# 787     32.92
# 988     17.54
# 623     53.30

# %%
0.0 in concrete['strength'].values
# Out:
# False

# %% [markdown]
# ### Quality Issues:
# 1. There are 25 duplicate rows.
# 2. "0.0" values instead of null.

# %% [markdown]
# ### Data Cleaning

# %%
concrete_clean = concrete.copy()

# %% [markdown]
# #### There are 25 duplicate rows.

# %% [markdown]
# #### Define:
# Remove the duplicate rows using the `drop_duplicates()` function.

# %% [markdown]
# #### Code:

# %%
concrete_clean.drop_duplicates(inplace = True, ignore_index = True)

# %% [markdown]
# #### Test

# %%
concrete_clean.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### "0.0" values instead of null.

# %% [markdown]
# #### Define:

# %% [markdown]
# #### Code:

# %%
concrete_clean = concrete_clean.replace(0.0,np.nan)
concrete_clean.dropna(inplace = True)
concrete_clean.reset_index(drop=True, inplace = True)

# %% [markdown]
# #### Test:

# %%
0.0 in concrete_clean['slag'].values
# Out:
# False

# %%
concrete_clean.shape
# Out:
# (225, 9)

# %% [markdown]
# # Exploratory Analysis

# %% [markdown]
# ## Univariate Exploration

# %% [markdown]
# #### Question:
# How does the distribution of "strength" of concrete looks?

# %% [markdown]
# #### Visualization

# %%
bin_edges = np.arange(concrete_clean['strength'].min(),concrete_clean['strength'].max() + 3.5, 3.5)
sb.displot(concrete_clean['strength'], bins = bin_edges);

# %% [markdown]
# #### Observation:
# An approximately normal distribution having 3-4 unusual spikes of strength values less than 40Mpa

# %% [markdown]
# #### Question:
# What is the shape of 'water' distribution plot?

# %% [markdown]
# #### Visualization:

# %%
bin_edges = np.arange(concrete_clean['water'].min(),concrete_clean['water'].max() + 5,5)
sb.displot(concrete_clean['water'], bins = bin_edges);

# %% [markdown]
# #### Observation:
# Almost all the water volume in the dataset are above 150, while a very few are above 220. I observe that water volumes of about 160 - 180 have the highest frequency.

# %% [markdown]
# ## Bivariate Exploration

# %% [markdown]
# #### Question:
# Is strength of concrete dependent on the quantity of cement?

# %% [markdown]
# #### Visualization:

# %%
sb.regplot(data= concrete_clean, x='cement',y='strength');

# %% [markdown]
# It can be observed that for the same quantity of cement, there are different levels of strength. This implies that within a range of cement quantity used, there is/are another variable(s) upon which a strength of concrete is dependent. However, generally the higher the quantity of cement the likeliness of a greater strength.
#
# A plot of strength against the proportion of water-to-cement (w/c) ratio should give a meaningful insight.

# %%
# create a w/c ratio column
concrete_clean['water_cmt_ratio'] = concrete_clean['water'] / concrete_clean['cement']
# create a new copy of dataframe
concrete_clean_plus = concrete_clean.copy()
# create plot of strength against the w/c ratio 
sb.regplot(data= concrete_clean_plus, x='water_cmt_ratio',y='strength', fit_reg = False);

# %% [markdown]
# #### Observation:
# It is observed that the lower the water-to-cement ratio, the increase in strength. Yet still as before, for an equal value of of water-to-cement ratio there are increasing levels of strength. This tells that there are other variable that come into play.

# %%
print(concrete_clean_plus['water_cmt_ratio'].max(),concrete_clean_plus['water_cmt_ratio'].min())
# Out:
# 1.6943450250536864 0.3632286995515695

# %%
# create a category of grades labelled (A-F) for the w/c ratio with a bin-size of 0.24
category = pd.cut(concrete_clean_plus.water_cmt_ratio, bins =[0.36,0.60,0.84,1.08,1.32,1.56,1.80], labels = ['A','B','C','D','E','F'])
# insert the new column 'water_cmt_grade' right next to the 10th column of the dataframe.
concrete_clean_plus.insert(9, 'water_cmt_grade', category)

# %%
concrete_clean_plus.head(5)
# Out:
#    cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0   168.9   42.2  124.3  158.3          10.8     1080.8    796.2   14
# 1   155.0  184.0  143.0  194.0           9.0      880.0    699.0   28
# 2   151.8  178.1  138.7  167.5          18.3      944.0    694.6   28
# 3   167.0  187.0  195.0  185.0           7.0      898.0    636.0   28
# 4   213.8   98.1   24.5  181.7           6.7     1066.0    785.5  100
#
#    strength water_cmt_grade  water_cmt_ratio
# 0     23.51               C         0.937241
# 1     28.99               D         1.251613
# 2     36.35               D         1.103426
# 3     23.89               D         1.107784
# 4     49.97               C         0.849860

# %%
concrete_clean_plus['water_cmt_grade'].value_counts(sort=False)
# Out:
# A    65
# B    46
# C    61
# D    34
# E    17
# F     2
# Name: water_cmt_grade, dtype: int64

# %% [markdown]
# #### Question:
# Which grade of w/c ratio in this dataset has the highest, and which has the least?

# %% [markdown]
# #### Visualization (univariate):

# %%
# convert to an ordered categorical datatype
g_class = ['A','B','C','D','E','F']
grade_class = pd.api.types.CategoricalDtype(ordered = True, categories = g_class)
concrete_clean_plus['water_cmt_grade'] = concrete_clean_plus['water_cmt_grade'].astype(grade_class);

# %%
# plot a barchart of w/c ratio grades
base_color = sb.color_palette()[0]
sb.countplot(data=concrete_clean_plus, x='water_cmt_grade', color = base_color);

# %% [markdown]
# #### Observation:
# Grade A has the highest occurence while Grade F has the least occurence. Grade C has the second highest occurence, followed by Grade B,D,E in that order.

# %% [markdown]
# #### Question:
# What is the grade - strength relationship across all water-to-cement grade in the dataset?

# %%
base_color = sb.color_palette()[0]

# %%
plt.figure(figsize = [20,5])
# Violin plot on the LHS
plt.subplot(1,2,1)
sb.violinplot(data=concrete_clean_plus, x='water_cmt_grade',y='strength', color= base_color);
# Box plot on the RHS
plt.subplot(1,2,2)
sb.boxplot(data=concrete_clean_plus, x='water_cmt_grade',y='strength');

# %% [markdown]
# #### Observation:
# The box plot on the rigth shows that the median strength of Grade-D concrete is the lowest of all the grades, while it also reveals that there is a linear decrease in median strength with Grade-A having the highest, followed by Grade-B then Grade-C. Interestingly, Grade-E concrete samples have a slightly higher median strength than the preceding Grade-D, and it also appears to be bimodal from the violin plot.
# Also, the shape (extremely skinny on each end and wide in the middle) of the distribution of Grade-D indicates that the strengths of concrete samples are highly concentrated around the median, likewise Grade-B.

# %% [markdown]
# Next, I'll be creating a new column to compute the fine-coarse aggregate ratio.

# %%
concrete_clean_plus['agg_ratio'] = concrete_clean_plus['fineagg'] / concrete_clean_plus['coarseagg']
concrete_clean_plus.head(5)
# Out:
#    cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0   168.9   42.2  124.3  158.3          10.8     1080.8    796.2   14
# 1   155.0  184.0  143.0  194.0           9.0      880.0    699.0   28
# 2   151.8  178.1  138.7  167.5          18.3      944.0    694.6   28
# 3   167.0  187.0  195.0  185.0           7.0      898.0    636.0   28
# 4   213.8   98.1   24.5  181.7           6.7     1066.0    785.5  100
#
#    strength water_cmt_grade  water_cmt_ratio  agg_ratio
# 0     23.51               C         0.937241   0.736677
# 1     28.99               D         1.251613   0.794318
# 2     36.35               D         1.103426   0.735805
# 3     23.89               D         1.107784   0.708241
# 4     49.97               C         0.849860   0.736867

# %% [markdown]
# #### Question:
# Does the fine-to-coarse aggregate ratio determine the amount of water required for a concrete mixture?

# %% [markdown]
# #### Visualization:

# %%
concrete_clean_plus['agg_ratio'].describe()
# Out:
# count    225.000000
# mean       0.802848
# std        0.083872
# min        0.654602
# 25%        0.736911
# 50%        0.776156
# 75%        0.851038
# max        1.066748
# Name: agg_ratio, dtype: float64

# %%
plt.figure(figsize = [6,4])
sb.regplot(data = concrete_clean_plus, x='agg_ratio', y='water');

# %% [markdown]
# #### Observation:
# No obvious relationship is observed.

# %% [markdown]
# #### Question:
# Does the aggregate ratio affects the strength of concrete?

# %% [markdown]
# #### Visualization:

# %%
plt.figure(figsize = [6,4])
sb.regplot(data = concrete_clean_plus, x='agg_ratio', y='strength');

# %% [markdown]
# #### Observation:
# No direct relationship is observed, but there are increasing level of strength for every range of aggregate ratio.
# So far I have discovered that the water-cement grade affects the strength of concrete, the amount of water used is not directly proportional to the aggregate ratio, likewise strength is not directly proportional to the aggregate ratio.

# %% [markdown]
# However there could be a relationship between the agg_ratio and the water-cement grade

# %%
plt.figure(figsize = [20,5])
# Violin plot on the LHS
plt.subplot(1,2,1)
sb.violinplot(data=concrete_clean_plus, x='water_cmt_grade',y='agg_ratio', color= base_color);
# Box plot on the RHS
plt.subplot(1,2,2)
sb.boxplot(data=concrete_clean_plus, x='water_cmt_grade',y='agg_ratio');

# %% [markdown]
# #### Observation:
# Grade-A and Grade-B has the greatest counts of high values of aggregate ratio. Although the lower grades of D & E have greater counts of high aggregate ratio values compared to Grade-C, they still have quite a lesser number of such observations compared to Grade-A and Grade-B.

# %% [markdown]
# #### Univariate plot of aggregate ratio

# %%
bin_edges = np.arange(concrete_clean_plus['agg_ratio'].min(),concrete_clean_plus['agg_ratio'].max() + 0.03,0.03)
sb.displot(concrete_clean_plus['agg_ratio'], bins = bin_edges);

# %% [markdown]
# #### Observation:
# From the univariate plot above, aggregate ratio of about 0.73 have a very high rate of occurence in the dataset.

# %% [markdown]
# A FacetGrid Plot can show how distributed the aggregate ratio values are across each water-cement grade of concretes.

# %%
bin_edges = np.arange(concrete_clean_plus['agg_ratio'].min(),concrete_clean_plus['agg_ratio'].max() + 0.03,0.03)
g = sb.FacetGrid(data = concrete_clean_plus, col = 'water_cmt_grade')
g.map(plt.hist, "agg_ratio", bins = bin_edges);

# %% [markdown]
# #### Question:
# What is the distribution of strength across each water_cmt_grade of concrete samples?

# %% [markdown]
# #### Visualization:

# %%
bin_edges = np.arange(concrete_clean['strength'].min(),concrete_clean['strength'].max() + 3.5, 3.5)
g = sb.FacetGrid(data = concrete_clean_plus, col = 'water_cmt_grade')
g.map(plt.hist, "strength");

# %% [markdown]
# #### Observation:
# Low quality water-cement grades D,E & F have maximum strength values of about 40, whereas higher grades of A,B,C have `strength` values that goes beyond 40MPa. One might wonder that since the barchart of `water_cmt_grade` shows that Grades A,B,C has the highest frequency in the concrete samples, thus the histogram of `strenght` should show a left-skewed or - in other words - a very spikes of high strength values greater than 40 MPa. However that was not the case, this facetgrid plot infact shows that this better grades of A,B,C contains very low `strength` values as well.
#
# This should not be considered as a contrast yet as it could be due to the quantity of cement used (which is different for all samples) or some other factors which really points to inaccurate mixture of components.

# %% [markdown]
# ## Multivariate Exploration:

# %% [markdown]
# #### Question:
# Is cement quantity proportional to strength?

# %%
g = sb.FacetGrid(data = concrete_clean_plus, col = 'water_cmt_grade')
g.map(plt.scatter, "cement", "strength");

# %% [markdown]
# #### Observation:
# Only water_cement grade A has quantity of cement of 300kg and above, while the rest has cement quantity lesser than 250 kg. Similarly as seen before the maximum strength observered decreases across the grades of Cement. Thus, generally the lesser the various quantites of cement used across each water-cement grade of concrete samples the lesser the maximum `strength` observed.

# %% [markdown]
# #### Question:
# Is superplastic quantity used directly proportional to strength ?

# %%
g = sb.FacetGrid(data = concrete_clean_plus, col = 'water_cmt_grade')
g.map(plt.scatter, "superplastic", "strength");

# %% [markdown]
# #### Observation:
# Grade-A contains concrete samples that used superplastic quantities of 15kg and greater than that, where as the other grades contains superplastic quantites lesser than that.

# %% [markdown]
# #### Question:
# Does the aggregate ratio increases or decreases with increasing strength?

# %% [markdown]
# #### Visualization:

# %%
plt.figure(figsize = [7,4])
plt.scatter(data = concrete_clean_plus, x = 'cement', y = 'strength', c = 'agg_ratio', cmap = 'viridis_r')
plt.colorbar();

# %% [markdown]
# #### Observation:
# No meaningful pattern is observed. Majority of the observations fall between the aggregate ratio range of 0.75 - 0.90

# %% [markdown]
# #### Question:
# Is there any relationship between the cement, slag and the compressive strength of concrete ?

# %%
plt.figure(figsize = [7,4])
plt.scatter(data = concrete_clean_plus, x = 'slag', y = 'cement', c = 'strength', cmap = 'viridis_r')
plt.colorbar()
plt.xlabel('slag')
plt.ylabel('cement');

# %% [markdown]
# #### Observation:
# There appears from the multivariate plot that at very high quantites (around 330 - 500 kg) of cement, little amount of slag was used (less than 30kg). Also when a moderate quantity of cement is used, either a moderate or a high quantity of slag is used.
# Generally, for a specific quantity range of slag it is observed that there is an improved compressive strength with increased quantity of cement.

# %%
category = pd.cut(concrete_clean_plus.strength, bins =[0,20,40,60,83], labels = ['Low','Moderate','High','Very High'])
concrete_clean_plus.insert(9, 'strength_level', category)

# %%
concrete_clean_plus.sample(5)
# Out:
#      cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 155   167.0   75.4  167.0  164.0           7.9     1007.3    770.1  100
# 160   146.5  114.6   89.3  201.9           8.8      860.0    829.5   28
# 224   276.4  116.0   90.3  179.6           8.9      870.1    768.3   28
# 39    178.0  129.8  118.6  179.9           3.6     1007.3    746.8   56
# 134   446.0   24.0   79.0  162.0          11.6      967.0    712.0    7
#
#      strength strength_level water_cmt_grade  water_cmt_ratio  agg_ratio
# 155     56.81           High               C         0.982036   0.764519
# 160     19.99            Low               E         1.378157   0.964535
# 224     44.28           High               B         0.649783   0.883002
# 39      48.59           High               C         1.010674   0.741388
# 134     39.30       Moderate               A         0.363229   0.736298

# %%
g = sb.FacetGrid(data = concrete_clean_plus, col = 'water_cmt_grade', row = 'strength_level', margin_titles = True)
g.map(plt.scatter, "slag", "cement");

# %% [markdown]
# #### Observation:
# 1. Overall the maximum compressive strength reduces from Grade A - F.
# 2. Down each column of grade, increase in slag quantity used increases the max compressive.

# %% [markdown]
# #### Bivariate plot of aggregate ratio across all levels of strength.
#
# ##### Visualization:

# %%
g = sb.FacetGrid(data = concrete_clean_plus, col = 'strength_level')
g.map(plt.hist, "agg_ratio");

# %% [markdown]
# ##### Observation:
# No trend or pattern is observed.
# Since almost all typical values of aggregate ratio exist across all levels of strength and across all levels of water-cement grade as well, the conclusion is that the mode of the aggregate ratio which occur between the range of 0.73 - 0.9 is probably too small to make quite a great significant difference in the compressive strengths of concretes taken in this sample.
